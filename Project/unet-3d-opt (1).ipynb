# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans22
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  

# neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt


# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

import warnings
warnings.filterwarnings('ignore')

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',   
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE - RED
    2 : 'EDEMA',  # Green
    3 : 'ENHANCING' # original 4 -> converted into 3 later, Yellow
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
#VOLUME_SLICES = 100  
VOLUME_SLICES = 48
VOLUME_START_AT = 22 # first slice of volume that we will include

IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_DEPTH = 48
IMG_CHANNELS = 3

# %%
TRAIN_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
VALIDATION_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/'
# TRAIN_DATASET_PATH = '../input/brats2020-simples/'
# VALIDATION_DATASET_PATH = '../input/brats2020-simples/'

# %%
test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t2.nii').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_image_t1[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_mask[60:-60,:,:]), 90, resize=True), cmap ='gray')

# %%
niimg = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii')
nimask = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii')

fig, axes = plt.subplots(nrows=4, figsize=(30, 40))


nlplt.plot_anat(niimg,
                title='BraTS20_Training_001_flair.nii plot_anat',
                axes=axes[0])

nlplt.plot_epi(niimg,
               title='BraTS20_Training_001_flair.nii plot_epi',
               axes=axes[1])

nlplt.plot_img(niimg,
               title='BraTS20_Training_001_flair.nii plot_img',
               axes=axes[2])

nlplt.plot_roi(nimask, 
               title='BraTS20_Training_001_flair.nii with mask plot_roi',
               bg_img=niimg, 
               axes=axes[3], cmap='Paired')

plt.show()

# %%
import tensorflow as tf
import numpy as np

# Dice Coefficient Metric
def dice_coef(y_true, y_pred, smooth=1e-9):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return tf.reduce_mean(dice)

# Jaccard Index (IoU) Metric
def jaccard_coef(y_true, y_pred, smooth=1e-9):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

# Precision Metric
def precision(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_positives = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    predicted_positives = tf.reduce_sum(y_pred, axis=[1, 2, 3])
    precision = true_positives / (predicted_positives + 1e-9)
    return tf.reduce_mean(precision)

# Sensitivity (Recall) Metric
def sensitivity(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_positives = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    actual_positives = tf.reduce_sum(y_true, axis=[1, 2, 3])
    sensitivity = true_positives / (actual_positives + 1e-9)
    return tf.reduce_mean(sensitivity)

# Specificity Metric
def specificity(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=[1, 2, 3])
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=[1, 2, 3])
    specificity = true_negatives / (true_negatives + false_positives + 1e-9)
    return tf.reduce_mean(specificity)

# Define Per-Class Dice Coefficients with Unique Names
def dice_coef_per_class(class_index, name):
    def dice_coef_class(y_true, y_pred):
        y_true_class = y_true[:, :, :, class_index]
        y_pred_class = y_pred[:, :, :, class_index]
        return dice_coef(y_true_class, y_pred_class)
    
    # Assign a unique name to the metric
    dice_coef_class.__name__ = name
    return dice_coef_class

# BCE + Dice Loss
def bce_dice_loss(y_true, y_pred):
    bce_loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice_loss = 1.0 - dice_coef(y_true, y_pred)
    return bce_loss + dice_loss

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Conv3DTranspose, concatenate, Dropout, Input, Add
from tensorflow.keras.models import Model

def double_conv_block(x, filters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal', dropout_rate=0.1):
    # First convolution
    x = Conv3D(filters, kernel_size, activation='relu', padding=padding, kernel_initializer=kernel_initializer)(x)
    x = Dropout(dropout_rate)(x)
    # Second convolution
    x = Conv3D(filters, kernel_size, activation='relu', padding=padding, kernel_initializer=kernel_initializer)(x)
    x = Dropout(dropout_rate)(x)
    return x

def residual_block(x, filters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal', dropout_rate=0.1):
    # Double convolution
    conv_out = double_conv_block(x, filters, kernel_size, padding, kernel_initializer, dropout_rate)
    # Residual connection
    residual = Conv3D(filters, (1, 1, 1), padding=padding, kernel_initializer=kernel_initializer)(x)
    out = Add()([conv_out, residual])
    return out

def build_unet(inputs, ker_init):
    num_classes = 4
    s = inputs  # (IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS)

    # Contraction path
    c1 = residual_block(s, 16, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = residual_block(p1, 32, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.1)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = residual_block(p2, 64, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.2)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = residual_block(p3, 128, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.2)
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(c4)
     
    c5 = residual_block(p4, 256, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.3)
    
    # Expansive path 
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = residual_block(u6, 128, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.2)
     
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = residual_block(u7, 64, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.2)
     
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = residual_block(u8, 32, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.1)
     
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = residual_block(u9, 16, kernel_size=(3, 3, 3), kernel_initializer=ker_init, dropout_rate=0.1)
     
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    model.summary()
    
    return model

# Define input layer
input_layer = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, 3))
model = build_unet(input_layer, 'he_normal')

# Compile the model
model.compile(
    loss=bce_dice_loss,  # Use your custom loss function
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core
        dice_coef_per_class(1, "dice_coef_edema"),     # Peritumoral Edema
        dice_coef_per_class(2, "dice_coef_enhancing"), # Enhancing Tumor
        jaccard_coef
    ]
)

print(model.input_shape)
print(model.output_shape)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 48 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 128, 128, 48, 1312        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 48, 0           conv3d[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 128, 48, 6928        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 48, 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 128, 48, 64          input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 48, 0           dropout_1[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 64, 64, 24, 1 0           add[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 64, 24, 3 13856       max_pooling3d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 24, 3 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 64, 64, 24, 3 27680       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 24, 3 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 64, 64, 24, 3 544         max_pooling3d[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 24, 3 0           dropout_3[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 12, 3 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 32, 12, 6 55360       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 12, 6 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 32, 32, 12, 6 110656      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 12, 6 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 32, 32, 12, 6 2112        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 12, 6 0           dropout_5[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 6, 64 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 16, 16, 6, 12 221312      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 6, 12 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 16, 16, 6, 12 442496      dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 6, 12 0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 16, 6, 12 8320        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 6, 12 0           dropout_7[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 3, 128) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 8, 8, 3, 256) 884992      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8, 8, 3, 256) 0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 8, 8, 3, 256) 1769728     dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 3, 256) 0           conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 8, 8, 3, 256) 33024       max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 3, 256) 0           dropout_9[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 16, 16, 6, 12 262272      add_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 6, 25 0           conv3d_transpose[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 16, 16, 6, 12 884864      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 6, 12 0           conv3d_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 16, 16, 6, 12 442496      dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 6, 12 0           conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 16, 16, 6, 12 32896       concatenate[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 6, 12 0           dropout_11[0][0]
#                                                                  conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 32, 32, 12, 6 65600       add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 12, 1 0           conv3d_transpose_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 32, 32, 12, 6 221248      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 12, 6 0           conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 32, 32, 12, 6 110656      dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 12, 6 0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 32, 32, 12, 6 8256        concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 12, 6 0           dropout_13[0][0]
#                                                                  conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 64, 64, 24, 3 16416       add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 24, 6 0           conv3d_transpose_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 64, 64, 24, 3 55328       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 24, 3 0           conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 64, 64, 24, 3 27680       dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 24, 3 0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 64, 64, 24, 3 2080        concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 24, 3 0           dropout_15[0][0]
#                                                                  conv3d_23[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 128, 128, 48, 4112        add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 48, 0           conv3d_transpose_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 128, 128, 48, 13840       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 48, 0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 128, 128, 48, 6928        dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 48, 0           conv3d_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 128, 128, 48, 528         concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 128, 128, 48, 0           dropout_17[0][0]
#                                                                  conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 128, 128, 48, 68          add_8[0][0]
# ==================================================================================================
# Total params: 5,733,652
# Trainable params: 5,733,652
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (None, 128, 128, 48, 3)
# (None, 128, 128, 48, 4)

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# file BraTS20_Training_355 has ill formatted name for for seg.nii file
#train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')
train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
my_test_ids = ['BraTS20_Training_319', 'BraTS20_Training_252', 'BraTS20_Training_195', 'BraTS20_Training_163', 'BraTS20_Training_213', 'BraTS20_Training_209', 'BraTS20_Training_337', 'BraTS20_Training_058', 'BraTS20_Training_278', 'BraTS20_Training_025', 'BraTS20_Training_143', 'BraTS20_Training_193', 'BraTS20_Training_008', 'BraTS20_Training_024', 'BraTS20_Training_219', 'BraTS20_Training_266', 'BraTS20_Training_282', 'BraTS20_Training_097', 'BraTS20_Training_217', 'BraTS20_Training_153', 'BraTS20_Training_299', 'BraTS20_Training_035', 'BraTS20_Training_349', 'BraTS20_Training_129', 'BraTS20_Training_115', 'BraTS20_Training_002', 'BraTS20_Training_311', 'BraTS20_Training_265', 'BraTS20_Training_231', 'BraTS20_Training_020', 'BraTS20_Training_031', 'BraTS20_Training_036', 'BraTS20_Training_131', 'BraTS20_Training_204', 'BraTS20_Training_347', 'BraTS20_Training_155', 'BraTS20_Training_161', 'BraTS20_Training_041', 'BraTS20_Training_107', 'BraTS20_Training_296', 'BraTS20_Training_047', 'BraTS20_Training_238', 'BraTS20_Training_322', 'BraTS20_Training_016', 'BraTS20_Training_060']

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

# Define the output directory path
output_dir = '/kaggle/working/'

# Function to save IDs to a text file in the output directory
def save_ids_to_file(ids, file_name):
    file_path = os.path.join(output_dir, file_name)
    with open(file_path, 'w') as file:
        for id_ in ids:
            file.write(id_ + '\n')

# Print the number of images in each set
print("Number of images in training set:", len(train_ids))
print("Number of images in validation set:", len(val_ids))
print("Number of images in test set:", len(test_ids))
# Out:
# Number of images in training set: 249
# Number of images in validation set: 74
# Number of images in test set: 45

# %%
def ResizeAndReduceSlices(nib,size,slices,gap):
    imgs = []
    for i in range(128):
        list1 = []
        for j in range(128):
            list2 = []
            for k in range(48):
                list2.append(0)
            list1.append(list2)
        imgs.append(list1)
    imgs = np.array(imgs)
    for i in range(slices):
        imgs[:,:,i] = cv2.resize(nib[:,:,int((i*gap)+20)],(size,size))
    return imgs

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH), batch_size = 1, n_channels = 3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size, *self.dim, self.n_channels)) # shape of (5, 128, 128, 128, 3)
        #y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size, *self.dim)) # shape of (5, 128, 128, 128)
        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata() 

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t2.nii'); 
            t2 = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            #seg=seg.astype(np.uint8)
            #seg[seg==4] = 3

            #temp_combined_images = np.stack([flair, ce, t2], axis=3)
            #temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
            #temp_mask = seg[56:184, 56:184, 13:141]
            
            slice_w = 25

            # (j +VOLUME_SLICES*c) 
            for j in range(VOLUME_SLICES):
                X[c,:,:,j,0] = cv2.resize(flair[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                X[c,:,:,j,1] = cv2.resize(ce[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                X[c,:,:,j,2] = cv2.resize(t2[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));

                #y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
                Y[c,:,:,j] = cv2.resize(seg[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                    
        # Generate masks
        #y[y==4] = 3;
        Y[Y==4] = 3;
        mask = tf.one_hot(Y, 4);
        #Y = tf.image.resize(mask, (IMG_HEIGHT, IMG_WIDTH));
        return X/np.max(X), mask
        #return temp_combined_images/np.max(temp_combined_images), temp_mask
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)
my_test_generator=DataGenerator(my_test_ids)

# %%
print(len(train_ids))
print(len(val_ids))
print(len(test_ids))
print(len(training_generator))
print(len(valid_generator))
print(len(test_generator))
img, mask = test_generator[0]
mask=np.argmax(mask, axis=4)[0,:,:,:]
print(mask.shape)
for n_slice in range(48):
# n_slice = 24
    plt.figure(figsize=(12, 8))
    plt.subplot(231)
    plt.title('Testing Image')
    plt.imshow(img[0,:,:,n_slice,0], cmap='gray')
    plt.subplot(232)
    plt.title('Testing Label')
    plt.imshow(mask[:,:,n_slice])
# Out:
# 249
# 74
# 45
# 249
# 74
# 45
# (128, 128, 48)

# %%
# show number of data for each dir 
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')
    plt.savefig('data2020.png')
    plt.show()
    
showDataLayout()

# %%
history =  model.fit(training_generator,
                    epochs=20,
                    steps_per_epoch=len(train_ids),
                    validation_data = valid_generator
                    )
# Out:
# Epoch 1/20
# 249/249 [==============================] - 242s 926ms/step - loss: 0.7872 - accuracy: 0.9770 - mean_io_u: 0.8266 - dice_coef: 0.2621 - precision: 0.2672 - sensitivity: 0.2467 - specificity: 0.7588 - dice_coef_necrotic: 0.9774 - dice_coef_edema: 0.9788 - dice_coef_enhancing: 0.9788 - jaccard_coef: 0.2590 - val_loss: 0.7552 - val_accuracy: 0.9838 - val_mean_io_u: 0.8005 - val_dice_coef: 0.2730 - val_precision: 0.2683 - val_sensitivity: 0.2507 - val_specificity: 0.7604 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2704
# Epoch 2/20
# 249/249 [==============================] - 125s 501ms/step - loss: 0.7523 - accuracy: 0.9863 - mean_io_u: 0.8574 - dice_coef: 0.2723 - precision: 0.2925 - sensitivity: 0.2530 - specificity: 0.7774 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2687 - val_loss: 0.7457 - val_accuracy: 0.9853 - val_mean_io_u: 0.8542 - val_dice_coef: 0.2797 - val_precision: 0.3738 - val_sensitivity: 0.2541 - val_specificity: 0.8214 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2748
# Epoch 3/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.7346 - accuracy: 0.9868 - mean_io_u: 0.8492 - dice_coef: 0.2883 - precision: 0.3753 - sensitivity: 0.2654 - specificity: 0.8002 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2788 - val_loss: 0.7215 - val_accuracy: 0.9858 - val_mean_io_u: 0.8549 - val_dice_coef: 0.2981 - val_precision: 0.4191 - val_sensitivity: 0.2742 - val_specificity: 0.8288 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.2843
# Epoch 4/20
# 249/249 [==============================] - 89s 355ms/step - loss: 0.7206 - accuracy: 0.9871 - mean_io_u: 0.8661 - dice_coef: 0.2989 - precision: 0.4510 - sensitivity: 0.2759 - specificity: 0.8244 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.2835 - val_loss: 0.6826 - val_accuracy: 0.9867 - val_mean_io_u: 0.8682 - val_dice_coef: 0.3352 - val_precision: 0.5210 - val_sensitivity: 0.2978 - val_specificity: 0.8536 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3090
# Epoch 5/20
# 249/249 [==============================] - 89s 355ms/step - loss: 0.6953 - accuracy: 0.9878 - mean_io_u: 0.8645 - dice_coef: 0.3235 - precision: 0.4969 - sensitivity: 0.2951 - specificity: 0.8383 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.2995 - val_loss: 0.6449 - val_accuracy: 0.9838 - val_mean_io_u: 0.8485 - val_dice_coef: 0.3822 - val_precision: 0.5797 - val_sensitivity: 0.3582 - val_specificity: 0.9288 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.3426
# Epoch 6/20
# 249/249 [==============================] - 88s 351ms/step - loss: 0.7166 - accuracy: 0.9870 - mean_io_u: 0.8540 - dice_coef: 0.3057 - precision: 0.4335 - sensitivity: 0.2808 - specificity: 0.8226 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.2893 - val_loss: 0.6958 - val_accuracy: 0.9859 - val_mean_io_u: 0.8181 - val_dice_coef: 0.3266 - val_precision: 0.5180 - val_sensitivity: 0.2958 - val_specificity: 0.8695 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3024
# Epoch 7/20
# 249/249 [==============================] - 88s 352ms/step - loss: 0.6870 - accuracy: 0.9878 - mean_io_u: 0.8694 - dice_coef: 0.3307 - precision: 0.5060 - sensitivity: 0.3005 - specificity: 0.8378 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3054 - val_loss: 0.6204 - val_accuracy: 0.9878 - val_mean_io_u: 0.8633 - val_dice_coef: 0.3956 - val_precision: 0.5974 - val_sensitivity: 0.3474 - val_specificity: 0.9015 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3513
# Epoch 8/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6642 - accuracy: 0.9883 - mean_io_u: 0.8785 - dice_coef: 0.3525 - precision: 0.5523 - sensitivity: 0.3212 - specificity: 0.8574 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3208 - val_loss: 0.6214 - val_accuracy: 0.9855 - val_mean_io_u: 0.8563 - val_dice_coef: 0.3992 - val_precision: 0.5849 - val_sensitivity: 0.3745 - val_specificity: 0.9065 - val_dice_coef_necrotic: 0.9999 - val_dice_coef_edema: 0.9999 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.3553
# Epoch 9/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6469 - accuracy: 0.9887 - mean_io_u: 0.8837 - dice_coef: 0.3694 - precision: 0.5897 - sensitivity: 0.3358 - specificity: 0.8647 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3317 - val_loss: 0.5864 - val_accuracy: 0.9878 - val_mean_io_u: 0.8801 - val_dice_coef: 0.4294 - val_precision: 0.5483 - val_sensitivity: 0.4192 - val_specificity: 0.9144 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3794
# Epoch 10/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6140 - accuracy: 0.9889 - mean_io_u: 0.8884 - dice_coef: 0.4014 - precision: 0.5849 - sensitivity: 0.3713 - specificity: 0.8751 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3564 - val_loss: 0.6933 - val_accuracy: 0.9858 - val_mean_io_u: 0.8642 - val_dice_coef: 0.3249 - val_precision: 0.5409 - val_sensitivity: 0.2906 - val_specificity: 0.8147 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3029
# Epoch 11/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6450 - accuracy: 0.9885 - mean_io_u: 0.8711 - dice_coef: 0.3726 - precision: 0.5684 - sensitivity: 0.3415 - specificity: 0.8551 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3350 - val_loss: 0.6104 - val_accuracy: 0.9872 - val_mean_io_u: 0.8562 - val_dice_coef: 0.4072 - val_precision: 0.5562 - val_sensitivity: 0.4060 - val_specificity: 0.9097 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3596
# Epoch 12/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.6391 - accuracy: 0.9887 - mean_io_u: 0.8769 - dice_coef: 0.3778 - precision: 0.5778 - sensitivity: 0.3427 - specificity: 0.8566 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3386 - val_loss: 0.5799 - val_accuracy: 0.9882 - val_mean_io_u: 0.9050 - val_dice_coef: 0.4355 - val_precision: 0.6014 - val_sensitivity: 0.4046 - val_specificity: 0.9018 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3808
# Epoch 13/20
# 249/249 [==============================] - 88s 354ms/step - loss: 0.6042 - accuracy: 0.9892 - mean_io_u: 0.8843 - dice_coef: 0.4108 - precision: 0.5992 - sensitivity: 0.3779 - specificity: 0.8747 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3629 - val_loss: 0.5981 - val_accuracy: 0.9882 - val_mean_io_u: 0.9212 - val_dice_coef: 0.4174 - val_precision: 0.5626 - val_sensitivity: 0.3755 - val_specificity: 0.8789 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3703
# Epoch 14/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5860 - accuracy: 0.9895 - mean_io_u: 0.8932 - dice_coef: 0.4284 - precision: 0.5889 - sensitivity: 0.3995 - specificity: 0.8869 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3753 - val_loss: 0.5782 - val_accuracy: 0.9886 - val_mean_io_u: 0.9135 - val_dice_coef: 0.4356 - val_precision: 0.6424 - val_sensitivity: 0.4053 - val_specificity: 0.8906 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3838
# Epoch 15/20
# 249/249 [==============================] - 88s 351ms/step - loss: 0.5580 - accuracy: 0.9901 - mean_io_u: 0.9042 - dice_coef: 0.4550 - precision: 0.6394 - sensitivity: 0.4279 - specificity: 0.9018 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3951 - val_loss: 0.5370 - val_accuracy: 0.9889 - val_mean_io_u: 0.9488 - val_dice_coef: 0.4783 - val_precision: 0.6320 - val_sensitivity: 0.4443 - val_specificity: 0.9057 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 0.9999 - val_dice_coef_enhancing: 0.9998 - val_jaccard_coef: 0.4172
# Epoch 16/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5987 - accuracy: 0.9889 - mean_io_u: 0.8855 - dice_coef: 0.4171 - precision: 0.5945 - sensitivity: 0.3843 - specificity: 0.8706 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3684 - val_loss: 0.5631 - val_accuracy: 0.9881 - val_mean_io_u: 0.8945 - val_dice_coef: 0.4517 - val_precision: 0.5821 - val_sensitivity: 0.4572 - val_specificity: 0.9208 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3978
# Epoch 17/20
# 249/249 [==============================] - 88s 352ms/step - loss: 0.5650 - accuracy: 0.9898 - mean_io_u: 0.8927 - dice_coef: 0.4486 - precision: 0.6312 - sensitivity: 0.4252 - specificity: 0.8953 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3902 - val_loss: 0.6061 - val_accuracy: 0.9877 - val_mean_io_u: 0.8668 - val_dice_coef: 0.4089 - val_precision: 0.6026 - val_sensitivity: 0.3653 - val_specificity: 0.8629 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3634
# Epoch 18/20
# 249/249 [==============================] - 88s 352ms/step - loss: 0.5705 - accuracy: 0.9898 - mean_io_u: 0.8960 - dice_coef: 0.4435 - precision: 0.6189 - sensitivity: 0.4185 - specificity: 0.8916 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3878 - val_loss: 0.5718 - val_accuracy: 0.9886 - val_mean_io_u: 0.9093 - val_dice_coef: 0.4422 - val_precision: 0.6039 - val_sensitivity: 0.4188 - val_specificity: 0.8837 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.3903
# Epoch 19/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5416 - accuracy: 0.9904 - mean_io_u: 0.9071 - dice_coef: 0.4708 - precision: 0.6433 - sensitivity: 0.4480 - specificity: 0.9062 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4093 - val_loss: 0.4953 - val_accuracy: 0.9899 - val_mean_io_u: 0.9111 - val_dice_coef: 0.5170 - val_precision: 0.6670 - val_sensitivity: 0.5010 - val_specificity: 0.9355 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4474
# Epoch 20/20
# 249/249 [==============================] - 88s 353ms/step - loss: 0.5136 - accuracy: 0.9908 - mean_io_u: 0.9142 - dice_coef: 0.4985 - precision: 0.6610 - sensitivity: 0.4718 - specificity: 0.9148 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4318 - val_loss: 0.5278 - val_accuracy: 0.9898 - val_mean_io_u: 0.9160 - val_dice_coef: 0.4846 - val_precision: 0.6488 - val_sensitivity: 0.4588 - val_specificity: 0.9212 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 0.9999 - val_jaccard_coef: 0.4257

# %%
model.save("model_my_3D_UNet.h5")

# %%
############ load trained model ################
model = tf.keras.models.load_model(
    '/kaggle/working/model_my_3D_UNet.h5',
    custom_objects={
        'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=4),  # Use 'MeanIoU' instead of 'accuracy'
        'dice_coef': dice_coef,
        'precision': precision,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'dice_coef_necrotic': dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core (class 0)
        'dice_coef_edema': dice_coef_per_class(1, "dice_coef_edema"),         # Peritumoral Edema (class 1)
        'dice_coef_enhancing': dice_coef_per_class(2, "dice_coef_enhancing")  # Enhancing Tumor (class 2)
    },
    compile=False  # Do not compile the model during loading
)



hist=history.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u_8'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u_8'],'r',label='Validation mean IOU')
ax[3].legend()
plt.savefig('training_result_2018.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17/3927384658.py in <module>
#      44 ax[2].legend()
#      45
# ---> 46 ax[3].plot(epoch,hist['mean_io_u_8'],'b',label='Training mean IOU')
#      47 ax[3].plot(epoch,hist['val_mean_io_u_8'],'r',label='Validation mean IOU')
#      48 ax[3].legend()
#
# KeyError: 'mean_io_u_8'

# %%
print(hist)

# %%
model = tf.keras.models.load_model(
    '/kaggle/working/model_my_3D_UNet.h5',
    custom_objects={
        'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=4),
        'dice_coef': dice_coef,
        'precision': precision,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'dice_coef_necrotic': dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core (class 0)
        'dice_coef_edema': dice_coef_per_class(1, "dice_coef_edema"),         # Peritumoral Edema (class 1)
        'dice_coef_enhancing': dice_coef_per_class(2, "dice_coef_enhancing")  # Enhancing Tumor (class 2)
    },
    compile=False
)
model.compile(
    loss=bce_dice_loss, 
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core
        dice_coef_per_class(1, "dice_coef_edema"),     # Peritumoral Edema
        dice_coef_per_class(2, "dice_coef_enhancing"), # Enhancing Tumor
        jaccard_coef
    ]
)

print("Evaluate on test data")
results = model.evaluate(my_test_generator, batch_size=100)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 45/45 [==============================] - 9s 176ms/step - loss: 0.5188 - accuracy: 0.9909 - mean_io_u_5: 0.9177 - dice_coef: 0.4919 - precision: 0.6567 - sensitivity: 0.4638 - specificity: 0.9248 - dice_coef_necrotic: 0.9997 - dice_coef_edema: 0.9995 - dice_coef_enhancing: 0.9992 - jaccard_coef: 0.4260
# test loss, test acc: [0.5188354253768921, 0.9909263253211975, 0.9177324771881104, 0.4918779134750366, 0.6566833257675171, 0.4637688994407654, 0.924802839756012, 0.999686598777771, 0.9995319843292236, 0.9991868734359741, 0.426047146320343]

# %%
# DataGenerator(ex: test_generator)=>tuple(images,mask)
# images=>[slice,depth,width,height,channels]
# mask=>[slice,depth,width,height,labels]

img_num = 33
test_img = my_test_generator.__getitem__(img_num)[0]    #tuple(image,mask) -> 0: image
test_mask =my_test_generator.__getitem__(img_num)[1]   #tuple(image,mask) -> 1: mask
test_mask_argmax=np.argmax(test_mask, axis=4)[0,:,:,:]

test_prediction = model.predict(test_img)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

print("test_prediction_shape: " + str(test_prediction.shape))
print("test_prediction_argmax_shape: " + str(test_prediction_argmax.shape))
print(np.unique(test_prediction_argmax))
print("test_img_shape: " + str(test_img.shape))
print("test_mask_shape: " + str(test_mask.shape))
print("test_mask_argmax: " + str(test_mask_argmax.shape))

n_slice = 15
for n_slice in range(48):
    plt.figure(figsize=(12, 8))
    plt.subplot(231)
    plt.title('Testing Image')
    plt.imshow(test_img[0,:,:,n_slice,0], cmap='gray')
    plt.subplot(232)
    plt.title('Testing Label')
    plt.imshow(test_mask_argmax[:,:,n_slice])
    plt.subplot(233)
    plt.title('Prediction on test image')
    plt.imshow(test_prediction_argmax[:,:,n_slice])
    plt.show()
# Out:
# test_prediction_shape: (1, 128, 128, 48, 4)
# test_prediction_argmax_shape: (128, 128, 48)
# [0 1 2]
# test_img_shape: (1, 128, 128, 48, 3)
# test_mask_shape: (1, 128, 128, 48, 4)
# test_mask_argmax: (128, 128, 48)

# %%
import matplotlib.pyplot as plt

img_num = 15
test_img = my_test_generator.__getitem__(img_num)[0]    #tuple(image,mask) -> 0: image
test_mask = my_test_generator.__getitem__(img_num)[1]   #tuple(image,mask) -> 1: mask
test_mask_argmax=np.argmax(test_mask, axis=4)[0,:,:,:]

test_prediction = model.predict(test_img)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

print("test_prediction_shape: " + str(test_prediction.shape))
print("test_prediction_argmax_shape: " + str(test_prediction_argmax.shape))
print(np.unique(test_prediction_argmax))
print("test_img_shape: " + str(test_img.shape))
print("test_mask_shape: " + str(test_mask.shape))
print("test_mask_argmax: " + str(test_mask_argmax.shape))

slice_index = 10  # Specify the index of the slice you want to display

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,slice_index,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,slice_index])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:,slice_index])
plt.show()
# Out:
# test_prediction_shape: (1, 128, 128, 48, 4)
# test_prediction_argmax_shape: (128, 128, 48)
# [0 1 2 3]
# test_img_shape: (1, 128, 128, 48, 3)
# test_mask_shape: (1, 128, 128, 48, 4)
# test_mask_argmax: (128, 128, 48)
