# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans22
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt

import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

import warnings
warnings.filterwarnings('ignore')

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',   
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE - RED
    2 : 'EDEMA',  # Green
    3 : 'ENHANCING' # original 4 -> converted into 3 later, Yellow
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
#VOLUME_SLICES = 100  
VOLUME_SLICES = 48
VOLUME_START_AT = 22 # first slice of volume that we will include

IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_DEPTH = 48
IMG_CHANNELS = 3

# %%
TRAIN_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
VALIDATION_DATASET_PATH = '../input/brats20-dataset-training-validation/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/'
# TRAIN_DATASET_PATH = '../input/brats2020-simples/'
# VALIDATION_DATASET_PATH = '../input/brats2020-simples/'

# %%
test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t2.nii').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_image_t1[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_mask[60:-60,:,:]), 90, resize=True), cmap ='gray')

# %%
niimg = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii')
nimask = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii')

fig, axes = plt.subplots(nrows=4, figsize=(30, 40))


nlplt.plot_anat(niimg,
                title='BraTS20_Training_001_flair.nii plot_anat',
                axes=axes[0])

nlplt.plot_epi(niimg,
               title='BraTS20_Training_001_flair.nii plot_epi',
               axes=axes[1])

nlplt.plot_img(niimg,
               title='BraTS20_Training_001_flair.nii plot_img',
               axes=axes[2])

nlplt.plot_roi(nimask, 
               title='BraTS20_Training_001_flair.nii with mask plot_roi',
               bg_img=niimg, 
               axes=axes[3], cmap='Paired')

plt.show()

# %%
import tensorflow as tf
import numpy as np

# Dice Coefficient Metric
def dice_coef(y_true, y_pred, smooth=1e-9):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return tf.reduce_mean(dice)

# Jaccard Index (IoU) Metric
def jaccard_coef(y_true, y_pred, smooth=1e-9):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

# Precision Metric
def precision(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_positives = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    predicted_positives = tf.reduce_sum(y_pred, axis=[1, 2, 3])
    precision = true_positives / (predicted_positives + 1e-9)
    return tf.reduce_mean(precision)

# Sensitivity (Recall) Metric
def sensitivity(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_positives = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    actual_positives = tf.reduce_sum(y_true, axis=[1, 2, 3])
    sensitivity = true_positives / (actual_positives + 1e-9)
    return tf.reduce_mean(sensitivity)

# Specificity Metric
def specificity(y_true, y_pred):
    y_pred = tf.cast(y_pred >= 0.5, dtype=tf.float32)  # Threshold predictions
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=[1, 2, 3])
    false_positives = tf.reduce_sum((1 - y_true) * y_pred, axis=[1, 2, 3])
    specificity = true_negatives / (true_negatives + false_positives + 1e-9)
    return tf.reduce_mean(specificity)

# Define Per-Class Dice Coefficients with Unique Names
def dice_coef_per_class(class_index, name):
    def dice_coef_class(y_true, y_pred):
        y_true_class = y_true[:, :, :, class_index]
        y_pred_class = y_pred[:, :, :, class_index]
        return dice_coef(y_true_class, y_pred_class)
    
    # Assign a unique name to the metric
    dice_coef_class.__name__ = name
    return dice_coef_class

# BCE + Dice Loss
def bce_dice_loss(y_true, y_pred):
    bce_loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice_loss = 1.0 - dice_coef(y_true, y_pred)
    return bce_loss + dice_loss

# %%
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Conv3DTranspose, concatenate, Dropout, Input, Add
from tensorflow.keras.models import Model

def double_conv_block(x, filters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal', dropout_rate=0.1):
    x = Conv3D(filters, kernel_size, activation='relu', padding=padding, kernel_initializer=kernel_initializer)(x)
    x = Dropout(dropout_rate)(x)
    x = Conv3D(filters, kernel_size, activation='relu', padding=padding, kernel_initializer=kernel_initializer)(x)
    x = Dropout(dropout_rate)(x)
    return x

def residual_block(x, filters, kernel_size=(3, 3, 3), padding='same', kernel_initializer='he_normal', dropout_rate=0.1):
    conv_out = double_conv_block(x, filters, kernel_size, padding, kernel_initializer, dropout_rate)
    residual = Conv3D(filters, (1, 1, 1), padding=padding, kernel_initializer=kernel_initializer)(x)
    out = Add()([conv_out, residual])
    return out

def build_unet3plus(inputs, ker_init):
    num_classes = 4
    s = inputs

    # Contraction path
    c1 = residual_block(s, 16, kernel_initializer=ker_init, dropout_rate=0.1)
    p1 = MaxPooling3D((2, 2, 2))(c1)
    
    c2 = residual_block(p1, 32, kernel_initializer=ker_init, dropout_rate=0.1)
    p2 = MaxPooling3D((2, 2, 2))(c2)
     
    c3 = residual_block(p2, 64, kernel_initializer=ker_init, dropout_rate=0.2)
    p3 = MaxPooling3D((2, 2, 2))(c3)
     
    c4 = residual_block(p3, 128, kernel_initializer=ker_init, dropout_rate=0.2)
    p4 = MaxPooling3D((2, 2, 2))(c4)
     
    c5 = residual_block(p4, 256, kernel_initializer=ker_init, dropout_rate=0.3)
    
    # Expansive path
    u6 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = residual_block(u6, 128, kernel_initializer=ker_init, dropout_rate=0.2)
    
    u7 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = residual_block(u7, 64, kernel_initializer=ker_init, dropout_rate=0.2)
    
    u8 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = residual_block(u8, 32, kernel_initializer=ker_init, dropout_rate=0.1)
    
    u9 = Conv3DTranspose(16, (2, 2, 2), strides=(2, 2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = residual_block(u9, 16, kernel_initializer=ker_init, dropout_rate=0.1)
    
    # Single output layer (remove deep supervision)
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(c9)
    
    model = Model(inputs=[inputs], outputs=outputs)
    model.summary()
    
    return model

# Define input layer
input_layer = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, 3))
model = build_unet3plus(input_layer, 'he_normal')

# Compile the model
model.compile(
    loss=bce_dice_loss,  # Use your custom loss function
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core
        dice_coef_per_class(1, "dice_coef_edema"),     # Peritumoral Edema
        dice_coef_per_class(2, "dice_coef_enhancing"), # Enhancing Tumor
        jaccard_coef
    ]
)

print(model.input_shape)
print(model.output_shape)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 48 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 128, 128, 48, 1312        input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 48, 0           conv3d[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 128, 48, 6928        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 48, 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 128, 128, 48, 64          input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 48, 0           dropout_1[0][0]
#                                                                  conv3d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 64, 64, 24, 1 0           add[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 64, 24, 3 13856       max_pooling3d[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 24, 3 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 64, 64, 24, 3 27680       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 24, 3 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 64, 64, 24, 3 544         max_pooling3d[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 24, 3 0           dropout_3[0][0]
#                                                                  conv3d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 12, 3 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 32, 32, 12, 6 55360       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 12, 6 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 32, 32, 12, 6 110656      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 12, 6 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 32, 32, 12, 6 2112        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 12, 6 0           dropout_5[0][0]
#                                                                  conv3d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 6, 64 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 16, 16, 6, 12 221312      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 6, 12 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 16, 16, 6, 12 442496      dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 6, 12 0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 16, 6, 12 8320        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 6, 12 0           dropout_7[0][0]
#                                                                  conv3d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 3, 128) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 8, 8, 3, 256) 884992      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 8, 8, 3, 256) 0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 8, 8, 3, 256) 1769728     dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 8, 8, 3, 256) 0           conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 8, 8, 3, 256) 33024       max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 3, 256) 0           dropout_9[0][0]
#                                                                  conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 16, 16, 6, 12 262272      add_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 6, 25 0           conv3d_transpose[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 16, 16, 6, 12 884864      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 16, 16, 6, 12 0           conv3d_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 16, 16, 6, 12 442496      dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 6, 12 0           conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 16, 16, 6, 12 32896       concatenate[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 6, 12 0           dropout_11[0][0]
#                                                                  conv3d_17[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 32, 32, 12, 6 65600       add_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 12, 1 0           conv3d_transpose_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 32, 32, 12, 6 221248      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 32, 32, 12, 6 0           conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 32, 32, 12, 6 110656      dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 32, 32, 12, 6 0           conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 32, 32, 12, 6 8256        concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 12, 6 0           dropout_13[0][0]
#                                                                  conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 64, 64, 24, 3 16416       add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 24, 6 0           conv3d_transpose_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 64, 64, 24, 3 55328       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64, 64, 24, 3 0           conv3d_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 64, 64, 24, 3 27680       dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 24, 3 0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 64, 64, 24, 3 2080        concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 24, 3 0           dropout_15[0][0]
#                                                                  conv3d_23[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 128, 128, 48, 4112        add_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 48, 0           conv3d_transpose_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 128, 128, 48, 13840       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 48, 0           conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 128, 128, 48, 6928        dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 48, 0           conv3d_25[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 128, 128, 48, 528         concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 128, 128, 48, 0           dropout_17[0][0]
#                                                                  conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 128, 128, 48, 68          add_8[0][0]
# ==================================================================================================
# Total params: 5,733,652
# Trainable params: 5,733,652
# Non-trainable params: 0
# __________________________________________________________________________________________________
# (None, 128, 128, 48, 3)
# (None, 128, 128, 48, 4)

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# file BraTS20_Training_355 has ill formatted name for for seg.nii file
#train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')
train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
my_test_ids = ['BraTS20_Training_319', 'BraTS20_Training_252', 'BraTS20_Training_195', 'BraTS20_Training_163', 'BraTS20_Training_213', 'BraTS20_Training_209', 'BraTS20_Training_337', 'BraTS20_Training_058', 'BraTS20_Training_278', 'BraTS20_Training_025', 'BraTS20_Training_143', 'BraTS20_Training_193', 'BraTS20_Training_008', 'BraTS20_Training_024', 'BraTS20_Training_219', 'BraTS20_Training_266', 'BraTS20_Training_282', 'BraTS20_Training_097', 'BraTS20_Training_217', 'BraTS20_Training_153', 'BraTS20_Training_299', 'BraTS20_Training_035', 'BraTS20_Training_349', 'BraTS20_Training_129', 'BraTS20_Training_115', 'BraTS20_Training_002', 'BraTS20_Training_311', 'BraTS20_Training_265', 'BraTS20_Training_231', 'BraTS20_Training_020', 'BraTS20_Training_031', 'BraTS20_Training_036', 'BraTS20_Training_131', 'BraTS20_Training_204', 'BraTS20_Training_347', 'BraTS20_Training_155', 'BraTS20_Training_161', 'BraTS20_Training_041', 'BraTS20_Training_107', 'BraTS20_Training_296', 'BraTS20_Training_047', 'BraTS20_Training_238', 'BraTS20_Training_322', 'BraTS20_Training_016', 'BraTS20_Training_060']

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

# Define the output directory path
output_dir = '/kaggle/working/'

# Function to save IDs to a text file in the output directory
def save_ids_to_file(ids, file_name):
    file_path = os.path.join(output_dir, file_name)
    with open(file_path, 'w') as file:
        for id_ in ids:
            file.write(id_ + '\n')

# Print the number of images in each set
print("Number of images in training set:", len(train_ids))
print("Number of images in validation set:", len(val_ids))
print("Number of images in test set:", len(test_ids))
# Out:
# Number of images in training set: 249
# Number of images in validation set: 74
# Number of images in test set: 45

# %%
def ResizeAndReduceSlices(nib,size,slices,gap):
    imgs = []
    for i in range(128):
        list1 = []
        for j in range(128):
            list2 = []
            for k in range(48):
                list2.append(0)
            list1.append(list2)
        imgs.append(list1)
    imgs = np.array(imgs)
    for i in range(slices):
        imgs[:,:,i] = cv2.resize(nib[:,:,int((i*gap)+20)],(size,size))
    return imgs

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH), batch_size = 1, n_channels = 3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size, *self.dim, self.n_channels)) # shape of (5, 128, 128, 128, 3)
        #y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size, *self.dim)) # shape of (5, 128, 128, 128)
        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata() 

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t2.nii'); 
            t2 = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            #seg=seg.astype(np.uint8)
            #seg[seg==4] = 3

            #temp_combined_images = np.stack([flair, ce, t2], axis=3)
            #temp_combined_images=temp_combined_images[56:184, 56:184, 13:141]
            #temp_mask = seg[56:184, 56:184, 13:141]
            
            slice_w = 25

            # (j +VOLUME_SLICES*c) 
            for j in range(VOLUME_SLICES):
                X[c,:,:,j,0] = cv2.resize(flair[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                X[c,:,:,j,1] = cv2.resize(ce[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                X[c,:,:,j,2] = cv2.resize(t2[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));

                #y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
                Y[c,:,:,j] = cv2.resize(seg[:,:,VOLUME_START_AT+int(j*2.5)], (IMG_HEIGHT, IMG_WIDTH));
                    
        # Generate masks
        #y[y==4] = 3;
        Y[Y==4] = 3;
        mask = tf.one_hot(Y, 4);
        #Y = tf.image.resize(mask, (IMG_HEIGHT, IMG_WIDTH));
        return X/np.max(X), mask
        #return temp_combined_images/np.max(temp_combined_images), temp_mask
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)
my_test_generator = DataGenerator(my_test_ids )

# %%
print(len(train_ids))
print(len(val_ids))
print(len(test_ids))
print(len(training_generator))
print(len(valid_generator))
print(len(test_generator))
img, mask = test_generator[0]
mask=np.argmax(mask, axis=4)[0,:,:,:]
print(mask.shape)
for n_slice in range(48):
# n_slice = 24
    plt.figure(figsize=(12, 8))
    plt.subplot(231)
    plt.title('Testing Image')
    plt.imshow(img[0,:,:,n_slice,0], cmap='gray')
    plt.subplot(232)
    plt.title('Testing Label')
    plt.imshow(mask[:,:,n_slice])
# Out:
# 249
# 74
# 45
# 249
# 74
# 45
# (128, 128, 48)

# %%
# show number of data for each dir 
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')
    plt.savefig('data2020.png')
    plt.show()
    
showDataLayout()

# %%
history =  model.fit(training_generator,
                    epochs=50,
                    steps_per_epoch=len(train_ids),
                    validation_data = valid_generator
                    )
# Out:
# Epoch 1/50
# 249/249 [==============================] - 281s 1s/step - loss: 0.7823 - accuracy: 0.9792 - mean_io_u: 0.8071 - dice_coef: 0.2654 - precision: 0.2665 - sensitivity: 0.2480 - specificity: 0.7560 - dice_coef_necrotic: 0.9860 - dice_coef_edema: 0.9876 - dice_coef_enhancing: 0.9881 - jaccard_coef: 0.2628 - val_loss: 0.7676 - val_accuracy: 0.9851 - val_mean_io_u: 0.7915 - val_dice_coef: 0.2616 - val_precision: 0.2463 - val_sensitivity: 0.2500 - val_specificity: 0.7500 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2598
# Epoch 2/50
# 249/249 [==============================] - 128s 512ms/step - loss: 0.7536 - accuracy: 0.9858 - mean_io_u: 0.8449 - dice_coef: 0.2728 - precision: 0.2978 - sensitivity: 0.2514 - specificity: 0.7674 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.2700 - val_loss: 0.7476 - val_accuracy: 0.9865 - val_mean_io_u: 0.8672 - val_dice_coef: 0.2735 - val_precision: 0.3772 - val_sensitivity: 0.2571 - val_specificity: 0.7952 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2671
# Epoch 3/50
# 249/249 [==============================] - 91s 366ms/step - loss: 0.7472 - accuracy: 0.9856 - mean_io_u: 0.8426 - dice_coef: 0.2769 - precision: 0.3342 - sensitivity: 0.2570 - specificity: 0.7823 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.2718 - val_loss: 0.7593 - val_accuracy: 0.9867 - val_mean_io_u: 0.7700 - val_dice_coef: 0.2711 - val_precision: 0.3722 - val_sensitivity: 0.2551 - val_specificity: 0.8233 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2658
# Epoch 4/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.7129 - accuracy: 0.9871 - mean_io_u: 0.8624 - dice_coef: 0.3080 - precision: 0.4386 - sensitivity: 0.2797 - specificity: 0.8174 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.2919 - val_loss: 0.7110 - val_accuracy: 0.9875 - val_mean_io_u: 0.8646 - val_dice_coef: 0.3089 - val_precision: 0.5048 - val_sensitivity: 0.2830 - val_specificity: 0.8437 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2897
# Epoch 5/50
# 249/249 [==============================] - 91s 365ms/step - loss: 0.6875 - accuracy: 0.9875 - mean_io_u: 0.8738 - dice_coef: 0.3304 - precision: 0.5063 - sensitivity: 0.3022 - specificity: 0.8460 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3062 - val_loss: 0.6625 - val_accuracy: 0.9889 - val_mean_io_u: 0.8708 - val_dice_coef: 0.3530 - val_precision: 0.5947 - val_sensitivity: 0.3165 - val_specificity: 0.8877 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3182
# Epoch 6/50
# 249/249 [==============================] - 90s 360ms/step - loss: 0.6976 - accuracy: 0.9871 - mean_io_u: 0.8484 - dice_coef: 0.3232 - precision: 0.4767 - sensitivity: 0.2942 - specificity: 0.8265 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3018 - val_loss: 0.7043 - val_accuracy: 0.9876 - val_mean_io_u: 0.8736 - val_dice_coef: 0.3123 - val_precision: 0.4830 - val_sensitivity: 0.2857 - val_specificity: 0.8314 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2922
# Epoch 7/50
# 249/249 [==============================] - 90s 361ms/step - loss: 0.6668 - accuracy: 0.9879 - mean_io_u: 0.8740 - dice_coef: 0.3505 - precision: 0.5512 - sensitivity: 0.3190 - specificity: 0.8562 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3187 - val_loss: 0.6329 - val_accuracy: 0.9878 - val_mean_io_u: 0.8979 - val_dice_coef: 0.3822 - val_precision: 0.5825 - val_sensitivity: 0.3845 - val_specificity: 0.8721 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3398
# Epoch 8/50
# 249/249 [==============================] - 90s 361ms/step - loss: 0.6474 - accuracy: 0.9878 - mean_io_u: 0.8845 - dice_coef: 0.3694 - precision: 0.5666 - sensitivity: 0.3389 - specificity: 0.8609 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3329 - val_loss: 0.7127 - val_accuracy: 0.9869 - val_mean_io_u: 0.9187 - val_dice_coef: 0.3045 - val_precision: 0.4490 - val_sensitivity: 0.2800 - val_specificity: 0.8107 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2876
# Epoch 9/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.6742 - accuracy: 0.9875 - mean_io_u: 0.8672 - dice_coef: 0.3437 - precision: 0.5197 - sensitivity: 0.3147 - specificity: 0.8523 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3165 - val_loss: 0.7228 - val_accuracy: 0.9868 - val_mean_io_u: 0.8577 - val_dice_coef: 0.2942 - val_precision: 0.4205 - val_sensitivity: 0.2724 - val_specificity: 0.8070 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2807
# Epoch 10/50
# 249/249 [==============================] - 91s 366ms/step - loss: 0.6381 - accuracy: 0.9886 - mean_io_u: 0.8837 - dice_coef: 0.3776 - precision: 0.5645 - sensitivity: 0.3510 - specificity: 0.8740 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3379 - val_loss: 0.5826 - val_accuracy: 0.9898 - val_mean_io_u: 0.8729 - val_dice_coef: 0.4309 - val_precision: 0.6506 - val_sensitivity: 0.4030 - val_specificity: 0.9062 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3782
# Epoch 11/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.5916 - accuracy: 0.9893 - mean_io_u: 0.8921 - dice_coef: 0.4227 - precision: 0.6261 - sensitivity: 0.3955 - specificity: 0.8950 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3722 - val_loss: 0.6742 - val_accuracy: 0.9881 - val_mean_io_u: 0.8571 - val_dice_coef: 0.3419 - val_precision: 0.5535 - val_sensitivity: 0.3055 - val_specificity: 0.8285 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3120
# Epoch 12/50
# 249/249 [==============================] - 90s 363ms/step - loss: 0.5671 - accuracy: 0.9898 - mean_io_u: 0.9007 - dice_coef: 0.4462 - precision: 0.6361 - sensitivity: 0.4174 - specificity: 0.9022 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3908 - val_loss: 0.5419 - val_accuracy: 0.9901 - val_mean_io_u: 0.9061 - val_dice_coef: 0.4699 - val_precision: 0.7014 - val_sensitivity: 0.4298 - val_specificity: 0.9041 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4060
# Epoch 13/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.5633 - accuracy: 0.9900 - mean_io_u: 0.9102 - dice_coef: 0.4498 - precision: 0.6298 - sensitivity: 0.4228 - specificity: 0.9105 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3925 - val_loss: 0.5943 - val_accuracy: 0.9899 - val_mean_io_u: 0.9028 - val_dice_coef: 0.4177 - val_precision: 0.6334 - val_sensitivity: 0.3863 - val_specificity: 0.9007 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3692
# Epoch 14/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.5573 - accuracy: 0.9901 - mean_io_u: 0.9112 - dice_coef: 0.4552 - precision: 0.6485 - sensitivity: 0.4304 - specificity: 0.9130 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.3984 - val_loss: 0.5089 - val_accuracy: 0.9910 - val_mean_io_u: 0.9003 - val_dice_coef: 0.5025 - val_precision: 0.7405 - val_sensitivity: 0.4547 - val_specificity: 0.9208 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4315
# Epoch 15/50
# 249/249 [==============================] - 90s 361ms/step - loss: 0.5301 - accuracy: 0.9906 - mean_io_u: 0.9140 - dice_coef: 0.4822 - precision: 0.6625 - sensitivity: 0.4587 - specificity: 0.9212 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4172 - val_loss: 0.5350 - val_accuracy: 0.9908 - val_mean_io_u: 0.9184 - val_dice_coef: 0.4762 - val_precision: 0.7115 - val_sensitivity: 0.4341 - val_specificity: 0.9116 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4114
# Epoch 16/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.5426 - accuracy: 0.9902 - mean_io_u: 0.9046 - dice_coef: 0.4708 - precision: 0.6544 - sensitivity: 0.4444 - specificity: 0.9105 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4090 - val_loss: 0.5866 - val_accuracy: 0.9895 - val_mean_io_u: 0.9307 - val_dice_coef: 0.4267 - val_precision: 0.6629 - val_sensitivity: 0.3939 - val_specificity: 0.8768 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3742
# Epoch 17/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.5282 - accuracy: 0.9906 - mean_io_u: 0.9045 - dice_coef: 0.4843 - precision: 0.6649 - sensitivity: 0.4572 - specificity: 0.9157 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4196 - val_loss: 0.5593 - val_accuracy: 0.9901 - val_mean_io_u: 0.8960 - val_dice_coef: 0.4535 - val_precision: 0.6389 - val_sensitivity: 0.4395 - val_specificity: 0.9005 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3988
# Epoch 18/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.6219 - accuracy: 0.9882 - mean_io_u: 0.8818 - dice_coef: 0.3965 - precision: 0.6028 - sensitivity: 0.3678 - specificity: 0.8643 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3515 - val_loss: 0.5872 - val_accuracy: 0.9896 - val_mean_io_u: 0.8944 - val_dice_coef: 0.4259 - val_precision: 0.6341 - val_sensitivity: 0.3981 - val_specificity: 0.8780 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3778
# Epoch 19/50
# 249/249 [==============================] - 90s 361ms/step - loss: 0.5734 - accuracy: 0.9891 - mean_io_u: 0.9014 - dice_coef: 0.4409 - precision: 0.6347 - sensitivity: 0.4130 - specificity: 0.8893 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3866 - val_loss: 0.5953 - val_accuracy: 0.9895 - val_mean_io_u: 0.9125 - val_dice_coef: 0.4177 - val_precision: 0.6545 - val_sensitivity: 0.3828 - val_specificity: 0.8780 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3683
# Epoch 20/50
# 249/249 [==============================] - 91s 365ms/step - loss: 0.5205 - accuracy: 0.9906 - mean_io_u: 0.9131 - dice_coef: 0.4917 - precision: 0.6767 - sensitivity: 0.4623 - specificity: 0.9176 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4259 - val_loss: 0.5054 - val_accuracy: 0.9907 - val_mean_io_u: 0.9009 - val_dice_coef: 0.5069 - val_precision: 0.7047 - val_sensitivity: 0.4637 - val_specificity: 0.9088 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4357
# Epoch 21/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.4983 - accuracy: 0.9910 - mean_io_u: 0.9201 - dice_coef: 0.5134 - precision: 0.6837 - sensitivity: 0.4869 - specificity: 0.9285 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4417 - val_loss: 0.5271 - val_accuracy: 0.9905 - val_mean_io_u: 0.9235 - val_dice_coef: 0.4851 - val_precision: 0.7068 - val_sensitivity: 0.4366 - val_specificity: 0.8819 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4202
# Epoch 22/50
# 249/249 [==============================] - 91s 365ms/step - loss: 0.5192 - accuracy: 0.9907 - mean_io_u: 0.9263 - dice_coef: 0.4925 - precision: 0.6823 - sensitivity: 0.4656 - specificity: 0.9231 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4253 - val_loss: 0.4761 - val_accuracy: 0.9915 - val_mean_io_u: 0.9090 - val_dice_coef: 0.5346 - val_precision: 0.7552 - val_sensitivity: 0.4978 - val_specificity: 0.9249 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4550
# Epoch 23/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.4886 - accuracy: 0.9912 - mean_io_u: 0.9217 - dice_coef: 0.5228 - precision: 0.6907 - sensitivity: 0.4962 - specificity: 0.9285 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4504 - val_loss: 0.4853 - val_accuracy: 0.9913 - val_mean_io_u: 0.9160 - val_dice_coef: 0.5252 - val_precision: 0.7272 - val_sensitivity: 0.4905 - val_specificity: 0.9207 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4554
# Epoch 24/50
# 249/249 [==============================] - 92s 368ms/step - loss: 0.4867 - accuracy: 0.9915 - mean_io_u: 0.9239 - dice_coef: 0.5241 - precision: 0.6923 - sensitivity: 0.5035 - specificity: 0.9324 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4521 - val_loss: 0.4691 - val_accuracy: 0.9915 - val_mean_io_u: 0.9376 - val_dice_coef: 0.5413 - val_precision: 0.7245 - val_sensitivity: 0.5227 - val_specificity: 0.9284 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4682
# Epoch 25/50
# 249/249 [==============================] - 90s 363ms/step - loss: 0.4807 - accuracy: 0.9913 - mean_io_u: 0.9260 - dice_coef: 0.5303 - precision: 0.7109 - sensitivity: 0.5050 - specificity: 0.9327 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4549 - val_loss: 0.4526 - val_accuracy: 0.9918 - val_mean_io_u: 0.9360 - val_dice_coef: 0.5577 - val_precision: 0.7403 - val_sensitivity: 0.5310 - val_specificity: 0.9252 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4810
# Epoch 26/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.4563 - accuracy: 0.9919 - mean_io_u: 0.9320 - dice_coef: 0.5536 - precision: 0.7125 - sensitivity: 0.5318 - specificity: 0.9420 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4760 - val_loss: 0.4373 - val_accuracy: 0.9920 - val_mean_io_u: 0.9479 - val_dice_coef: 0.5729 - val_precision: 0.7661 - val_sensitivity: 0.5310 - val_specificity: 0.9208 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4919
# Epoch 27/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.4673 - accuracy: 0.9918 - mean_io_u: 0.9357 - dice_coef: 0.5429 - precision: 0.7071 - sensitivity: 0.5177 - specificity: 0.9370 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4651 - val_loss: 0.4873 - val_accuracy: 0.9915 - val_mean_io_u: 0.9434 - val_dice_coef: 0.5227 - val_precision: 0.7085 - val_sensitivity: 0.5145 - val_specificity: 0.9405 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4546
# Epoch 28/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.4935 - accuracy: 0.9907 - mean_io_u: 0.9280 - dice_coef: 0.5183 - precision: 0.6927 - sensitivity: 0.4987 - specificity: 0.9309 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4462 - val_loss: 0.5496 - val_accuracy: 0.9902 - val_mean_io_u: 0.8972 - val_dice_coef: 0.4629 - val_precision: 0.6920 - val_sensitivity: 0.4379 - val_specificity: 0.9010 - val_dice_coef_necrotic: 0.9994 - val_dice_coef_edema: 0.9999 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4021
# Epoch 29/50
# 249/249 [==============================] - 90s 363ms/step - loss: 0.4882 - accuracy: 0.9913 - mean_io_u: 0.9237 - dice_coef: 0.5227 - precision: 0.7063 - sensitivity: 0.4952 - specificity: 0.9284 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4492 - val_loss: 0.4331 - val_accuracy: 0.9920 - val_mean_io_u: 0.9347 - val_dice_coef: 0.5769 - val_precision: 0.7588 - val_sensitivity: 0.5483 - val_specificity: 0.9360 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4947
# Epoch 30/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.4571 - accuracy: 0.9918 - mean_io_u: 0.9307 - dice_coef: 0.5529 - precision: 0.7150 - sensitivity: 0.5315 - specificity: 0.9407 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4734 - val_loss: 0.4080 - val_accuracy: 0.9918 - val_mean_io_u: 0.9056 - val_dice_coef: 0.6034 - val_precision: 0.7313 - val_sensitivity: 0.5670 - val_specificity: 0.9536 - val_dice_coef_necrotic: 0.9999 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.5119
# Epoch 31/50
# 249/249 [==============================] - 90s 360ms/step - loss: 0.4628 - accuracy: 0.9916 - mean_io_u: 0.9219 - dice_coef: 0.5479 - precision: 0.7131 - sensitivity: 0.5226 - specificity: 0.9352 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4681 - val_loss: 0.4252 - val_accuracy: 0.9922 - val_mean_io_u: 0.9361 - val_dice_coef: 0.5846 - val_precision: 0.7673 - val_sensitivity: 0.5571 - val_specificity: 0.9348 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.5021
# Epoch 32/50
# 249/249 [==============================] - 90s 363ms/step - loss: 0.4519 - accuracy: 0.9920 - mean_io_u: 0.9321 - dice_coef: 0.5580 - precision: 0.7155 - sensitivity: 0.5364 - specificity: 0.9421 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4779 - val_loss: 0.4466 - val_accuracy: 0.9921 - val_mean_io_u: 0.9288 - val_dice_coef: 0.5630 - val_precision: 0.7451 - val_sensitivity: 0.5316 - val_specificity: 0.9354 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4825
# Epoch 33/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.4448 - accuracy: 0.9922 - mean_io_u: 0.9355 - dice_coef: 0.5647 - precision: 0.7229 - sensitivity: 0.5391 - specificity: 0.9453 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4833 - val_loss: 0.4130 - val_accuracy: 0.9918 - val_mean_io_u: 0.9355 - val_dice_coef: 0.5970 - val_precision: 0.7460 - val_sensitivity: 0.5785 - val_specificity: 0.9585 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.5071
# Epoch 34/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.4422 - accuracy: 0.9922 - mean_io_u: 0.9432 - dice_coef: 0.5672 - precision: 0.7191 - sensitivity: 0.5400 - specificity: 0.9482 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4845 - val_loss: 0.4322 - val_accuracy: 0.9917 - val_mean_io_u: 0.9470 - val_dice_coef: 0.5778 - val_precision: 0.7440 - val_sensitivity: 0.5433 - val_specificity: 0.9355 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4871
# Epoch 35/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.5974 - accuracy: 0.9881 - mean_io_u: 0.8501 - dice_coef: 0.4289 - precision: 0.5919 - sensitivity: 0.4081 - specificity: 0.8706 - dice_coef_necrotic: 0.9995 - dice_coef_edema: 0.9993 - dice_coef_enhancing: 0.9994 - jaccard_coef: 0.3782 - val_loss: 0.7909 - val_accuracy: 0.9851 - val_mean_io_u: 0.3891 - val_dice_coef: 0.2619 - val_precision: 0.2722 - val_sensitivity: 0.2501 - val_specificity: 0.7516 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.2599
# Epoch 36/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.6962 - accuracy: 0.9869 - mean_io_u: 0.7052 - dice_coef: 0.3286 - precision: 0.4752 - sensitivity: 0.3016 - specificity: 0.8026 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3042 - val_loss: 0.6396 - val_accuracy: 0.9882 - val_mean_io_u: 0.7092 - val_dice_coef: 0.3775 - val_precision: 0.5667 - val_sensitivity: 0.3378 - val_specificity: 0.8443 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3357
# Epoch 37/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.6011 - accuracy: 0.9886 - mean_io_u: 0.7996 - dice_coef: 0.4149 - precision: 0.6082 - sensitivity: 0.3766 - specificity: 0.8625 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3639 - val_loss: 0.5590 - val_accuracy: 0.9895 - val_mean_io_u: 0.8158 - val_dice_coef: 0.4543 - val_precision: 0.6800 - val_sensitivity: 0.4123 - val_specificity: 0.8739 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.3942
# Epoch 38/50
# 249/249 [==============================] - 91s 366ms/step - loss: 0.5551 - accuracy: 0.9896 - mean_io_u: 0.8800 - dice_coef: 0.4587 - precision: 0.6526 - sensitivity: 0.4309 - specificity: 0.8897 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.3973 - val_loss: 0.5529 - val_accuracy: 0.9898 - val_mean_io_u: 0.8761 - val_dice_coef: 0.4597 - val_precision: 0.6994 - val_sensitivity: 0.4169 - val_specificity: 0.8811 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4007
# Epoch 39/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.5303 - accuracy: 0.9905 - mean_io_u: 0.9126 - dice_coef: 0.4816 - precision: 0.6771 - sensitivity: 0.4552 - specificity: 0.9097 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4167 - val_loss: 0.4671 - val_accuracy: 0.9911 - val_mean_io_u: 0.9193 - val_dice_coef: 0.5438 - val_precision: 0.7489 - val_sensitivity: 0.5079 - val_specificity: 0.9236 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4655
# Epoch 40/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.5102 - accuracy: 0.9907 - mean_io_u: 0.9213 - dice_coef: 0.5017 - precision: 0.6972 - sensitivity: 0.4780 - specificity: 0.9199 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4329 - val_loss: 0.4563 - val_accuracy: 0.9915 - val_mean_io_u: 0.9320 - val_dice_coef: 0.5544 - val_precision: 0.7482 - val_sensitivity: 0.5155 - val_specificity: 0.9209 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4772
# Epoch 41/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.4656 - accuracy: 0.9918 - mean_io_u: 0.9333 - dice_coef: 0.5448 - precision: 0.7103 - sensitivity: 0.5169 - specificity: 0.9360 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4664 - val_loss: 0.4785 - val_accuracy: 0.9913 - val_mean_io_u: 0.9359 - val_dice_coef: 0.5323 - val_precision: 0.7422 - val_sensitivity: 0.4892 - val_specificity: 0.9047 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4594
# Epoch 42/50
# 249/249 [==============================] - 90s 360ms/step - loss: 0.4677 - accuracy: 0.9918 - mean_io_u: 0.9360 - dice_coef: 0.5424 - precision: 0.7199 - sensitivity: 0.5172 - specificity: 0.9370 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4652 - val_loss: 0.4922 - val_accuracy: 0.9914 - val_mean_io_u: 0.9405 - val_dice_coef: 0.5183 - val_precision: 0.7210 - val_sensitivity: 0.4937 - val_specificity: 0.9337 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4449
# Epoch 43/50
# 249/249 [==============================] - 91s 367ms/step - loss: 0.4613 - accuracy: 0.9919 - mean_io_u: 0.9398 - dice_coef: 0.5486 - precision: 0.7110 - sensitivity: 0.5197 - specificity: 0.9388 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4702 - val_loss: 0.4291 - val_accuracy: 0.9922 - val_mean_io_u: 0.9560 - val_dice_coef: 0.5807 - val_precision: 0.7729 - val_sensitivity: 0.5464 - val_specificity: 0.9294 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4991
# Epoch 44/50
# 249/249 [==============================] - 91s 363ms/step - loss: 0.4495 - accuracy: 0.9920 - mean_io_u: 0.9385 - dice_coef: 0.5604 - precision: 0.7194 - sensitivity: 0.5328 - specificity: 0.9417 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4804 - val_loss: 0.5111 - val_accuracy: 0.9910 - val_mean_io_u: 0.9604 - val_dice_coef: 0.5000 - val_precision: 0.7248 - val_sensitivity: 0.4684 - val_specificity: 0.9165 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4312
# Epoch 45/50
# 249/249 [==============================] - 90s 360ms/step - loss: 0.4628 - accuracy: 0.9918 - mean_io_u: 0.9414 - dice_coef: 0.5472 - precision: 0.7154 - sensitivity: 0.5241 - specificity: 0.9400 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4694 - val_loss: 0.4723 - val_accuracy: 0.9914 - val_mean_io_u: 0.9750 - val_dice_coef: 0.5407 - val_precision: 0.7554 - val_sensitivity: 0.4989 - val_specificity: 0.9062 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4633
# Epoch 46/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.4501 - accuracy: 0.9921 - mean_io_u: 0.9441 - dice_coef: 0.5596 - precision: 0.7234 - sensitivity: 0.5367 - specificity: 0.9425 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4795 - val_loss: 0.4183 - val_accuracy: 0.9923 - val_mean_io_u: 0.9485 - val_dice_coef: 0.5912 - val_precision: 0.7608 - val_sensitivity: 0.5532 - val_specificity: 0.9393 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.5048
# Epoch 47/50
# 249/249 [==============================] - 91s 365ms/step - loss: 0.4492 - accuracy: 0.9919 - mean_io_u: 0.9393 - dice_coef: 0.5609 - precision: 0.7249 - sensitivity: 0.5345 - specificity: 0.9427 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9996 - jaccard_coef: 0.4810 - val_loss: 0.4518 - val_accuracy: 0.9918 - val_mean_io_u: 0.9469 - val_dice_coef: 0.5586 - val_precision: 0.7506 - val_sensitivity: 0.5133 - val_specificity: 0.9253 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4762
# Epoch 48/50
# 249/249 [==============================] - 91s 364ms/step - loss: 0.4460 - accuracy: 0.9921 - mean_io_u: 0.9409 - dice_coef: 0.5638 - precision: 0.7183 - sensitivity: 0.5380 - specificity: 0.9445 - dice_coef_necrotic: 0.9998 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4830 - val_loss: 0.4288 - val_accuracy: 0.9923 - val_mean_io_u: 0.9496 - val_dice_coef: 0.5808 - val_precision: 0.7653 - val_sensitivity: 0.5637 - val_specificity: 0.9467 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.5017
# Epoch 49/50
# 249/249 [==============================] - 91s 365ms/step - loss: 0.4441 - accuracy: 0.9922 - mean_io_u: 0.9438 - dice_coef: 0.5653 - precision: 0.7221 - sensitivity: 0.5390 - specificity: 0.9442 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4840 - val_loss: 0.4414 - val_accuracy: 0.9919 - val_mean_io_u: 0.9356 - val_dice_coef: 0.5687 - val_precision: 0.7387 - val_sensitivity: 0.5470 - val_specificity: 0.9462 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.4865
# Epoch 50/50
# 249/249 [==============================] - 90s 362ms/step - loss: 0.4336 - accuracy: 0.9924 - mean_io_u: 0.9456 - dice_coef: 0.5756 - precision: 0.7312 - sensitivity: 0.5507 - specificity: 0.9471 - dice_coef_necrotic: 0.9999 - dice_coef_edema: 0.9998 - dice_coef_enhancing: 0.9997 - jaccard_coef: 0.4927 - val_loss: 0.3955 - val_accuracy: 0.9925 - val_mean_io_u: 0.9336 - val_dice_coef: 0.6139 - val_precision: 0.7487 - val_sensitivity: 0.5858 - val_specificity: 0.9575 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_jaccard_coef: 0.5244

# %%
model.save("model_my_3Dplus_UNet.h5")

# %%
############ load trained model ################
model = tf.keras.models.load_model(
    '/kaggle/working/model_my_3Dplus_UNet.h5',
    custom_objects={
        'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=4),  # Use 'MeanIoU' instead of 'accuracy'
        'dice_coef': dice_coef,
        'precision': precision,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'dice_coef_necrotic': dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core (class 0)
        'dice_coef_edema': dice_coef_per_class(1, "dice_coef_edema"),         # Peritumoral Edema (class 1)
        'dice_coef_enhancing': dice_coef_per_class(2, "dice_coef_enhancing")  # Enhancing Tumor (class 2)
    },
    compile=False 
)


############### ########## ####### #######

hist=history.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u_24'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u_24'],'r',label='Validation mean IOU')
ax[3].legend()
plt.savefig('training_result_2018.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17/193183488.py in <module>
#      45 ax[2].legend()
#      46
# ---> 47 ax[3].plot(epoch,hist['mean_io_u_24'],'b',label='Training mean IOU')
#      48 ax[3].plot(epoch,hist['val_mean_io_u_24'],'r',label='Validation mean IOU')
#      49 ax[3].legend()
#
# KeyError: 'mean_io_u_24'

# %%
model = tf.keras.models.load_model(
    '/kaggle/working/model_my_3Dplus_UNet.h5',
    custom_objects={
        'MeanIoU': tf.keras.metrics.MeanIoU(num_classes=4),
        'dice_coef': dice_coef,
        'precision': precision,
        'sensitivity': sensitivity,
        'specificity': specificity,
        'dice_coef_necrotic': dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core (class 0)
        'dice_coef_edema': dice_coef_per_class(1, "dice_coef_edema"),         # Peritumoral Edema (class 1)
        'dice_coef_enhancing': dice_coef_per_class(2, "dice_coef_enhancing")  # Enhancing Tumor (class 2)
    },
    compile=False  # Do not compile the model during loading
)
model.compile(
    loss=bce_dice_loss, 
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_per_class(0, "dice_coef_necrotic"),  # Necrotic Core
        dice_coef_per_class(1, "dice_coef_edema"),     # Peritumoral Edema
        dice_coef_per_class(2, "dice_coef_enhancing"), # Enhancing Tumor
        jaccard_coef
    ]
)

print("Evaluate on test data")
results = model.evaluate(my_test_generator, batch_size=100)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 45/45 [==============================] - 14s 289ms/step - loss: 0.3778 - accuracy: 0.9932 - mean_io_u_3: 0.9413 - dice_coef: 0.6308 - precision: 0.7470 - sensitivity: 0.5979 - specificity: 0.9626 - dice_coef_necrotic: 0.9996 - dice_coef_edema: 0.9996 - dice_coef_enhancing: 0.9993 - jaccard_coef: 0.5388
# test loss, test acc: [0.37781885266304016, 0.9931906461715698, 0.9412600994110107, 0.6308425664901733, 0.7470288872718811, 0.5979397296905518, 0.962642252445221, 0.9996353387832642, 0.9995666742324829, 0.9993095993995667, 0.5387992262840271]

# %%
# DataGenerator(ex: test_generator)=>tuple(images,mask)
# images=>[slice,depth,width,height,channels]
# mask=>[slice,depth,width,height,labels]

img_num = 33
test_img = test_generator.__getitem__(img_num)[0]    #tuple(image,mask) -> 0: image
test_mask = test_generator.__getitem__(img_num)[1]   #tuple(image,mask) -> 1: mask
test_mask_argmax=np.argmax(test_mask, axis=4)[0,:,:,:]

test_prediction = model.predict(test_img)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

print("test_prediction_shape: " + str(test_prediction.shape))
print("test_prediction_argmax_shape: " + str(test_prediction_argmax.shape))
print(np.unique(test_prediction_argmax))
print("test_img_shape: " + str(test_img.shape))
print("test_mask_shape: " + str(test_mask.shape))
print("test_mask_argmax: " + str(test_mask_argmax.shape))

n_slice = 15
for n_slice in range(48):
    plt.figure(figsize=(12, 8))
    plt.subplot(231)
    plt.title('Testing Image')
    plt.imshow(test_img[0,:,:,n_slice,0], cmap='gray')
    plt.subplot(232)
    plt.title('Testing Label')
    plt.imshow(test_mask_argmax[:,:,n_slice])
    plt.subplot(233)
    plt.title('Prediction on test image')
    plt.imshow(test_prediction_argmax[:,:,n_slice])
    plt.show()
# Out:
# test_prediction_shape: (1, 128, 128, 48, 4)
# test_prediction_argmax_shape: (128, 128, 48)
# [0 1 2 3]
# test_img_shape: (1, 128, 128, 48, 3)
# test_mask_shape: (1, 128, 128, 48, 4)
# test_mask_argmax: (128, 128, 48)

# %%
import matplotlib.pyplot as plt

img_num = 19
test_img = test_generator.__getitem__(img_num)[0]    #tuple(image,mask) -> 0: image
test_mask = test_generator.__getitem__(img_num)[1]   #tuple(image,mask) -> 1: mask
test_mask_argmax=np.argmax(test_mask, axis=4)[0,:,:,:]

test_prediction = model.predict(test_img)
test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]

print("test_prediction_shape: " + str(test_prediction.shape))
print("test_prediction_argmax_shape: " + str(test_prediction_argmax.shape))
print(np.unique(test_prediction_argmax))
print("test_img_shape: " + str(test_img.shape))
print("test_mask_shape: " + str(test_mask.shape))
print("test_mask_argmax: " + str(test_mask_argmax.shape))

slice_index = 19

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0,:,:,slice_index,0], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,slice_index])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:,slice_index])
plt.show()
# Out:
# test_prediction_shape: (1, 128, 128, 48, 4)
# test_prediction_argmax_shape: (128, 128, 48)
# [0 1 2 3]
# test_img_shape: (1, 128, 128, 48, 3)
# test_mask_shape: (1, 128, 128, 48, 4)
# test_mask_argmax: (128, 128, 48)
